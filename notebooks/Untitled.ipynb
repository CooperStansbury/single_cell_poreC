# %%
import pandas as pd

import sys

sys.path.append("../kung_paohvis/")

import file_io as _io

# %%
parq_path = "../development/ParquetExtraction/02"

df = _io.read_parquet_dir(parq_path)
print(df.shape)
# Out:
# (459029, 28)

# %%
df = pd.read_csv('../outputs/raw_align_table_2021-07-15.csv')
df.shape
# Out:
# (373592, 17)

# %%
df = pd.read_csv('../outputs/diagnstics_2021-07-15.csv')
df
# Out:
#                             parameter          value    stage
# 0                      n_unique_reads   50000.000000  initial
# 1                         n_fragments  373592.000000  initial
# 2                  n_unique_fragments   88172.000000  initial
# 3                    mean_read_length    4490.355080  initial
# 4                     std_read_length    3399.176545  initial
# 5                     max_read_length   35072.000000  initial
# 6                     min_read_length     168.000000  initial
# 7              mean_read_mapping_qual      73.680087  initial
# 8               std_read_mapping_qual      83.503796  initial
# 9               max_read_mapping_qual     250.000000  initial
# 10              min_read_mapping_qual       0.000000  initial
# 11        mean_read_perc_of_alignment      82.105351  initial
# 12         std_read_perc_of_alignment      21.848573  initial
# 13         max_read_perc_of_alignment     100.000000  initial
# ...
